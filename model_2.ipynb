# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\programdata\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    6991 non-null   object
#  1   koi_fpflag_nt      6991 non-null   int64
#  2   koi_fpflag_ss      6991 non-null   int64
#  3   koi_fpflag_co      6991 non-null   int64
#  4   koi_fpflag_ec      6991 non-null   int64
#  5   koi_period         6991 non-null   float64
#  6   koi_period_err1    6991 non-null   float64
#  7   koi_period_err2    6991 non-null   float64
#  8   koi_time0bk        6991 non-null   float64
#  9   koi_time0bk_err1   6991 non-null   float64
#  10  koi_time0bk_err2   6991 non-null   float64
#  11  koi_impact         6991 non-null   float64
#  12  koi_impact_err1    6991 non-null   float64
#  13  koi_impact_err2    6991 non-null   float64
#  14  koi_duration       6991 non-null   float64
#  15  koi_duration_err1  6991 non-null   float64
#  16  koi_duration_err2  6991 non-null   float64
#  17  koi_depth          6991 non-null   float64
#  18  koi_depth_err1     6991 non-null   float64
#  19  koi_depth_err2     6991 non-null   float64
#  20  koi_prad           6991 non-null   float64
#  21  koi_prad_err1      6991 non-null   float64
#  22  koi_prad_err2      6991 non-null   float64
#  23  koi_teq            6991 non-null   int64
#  24  koi_insol          6991 non-null   float64
#  25  koi_insol_err1     6991 non-null   float64
#  26  koi_insol_err2     6991 non-null   float64
#  27  koi_model_snr      6991 non-null   float64
#  28  koi_tce_plnt_num   6991 non-null   int64
#  29  koi_steff          6991 non-null   int64
#  30  koi_steff_err1     6991 non-null   int64
#  31  koi_steff_err2     6991 non-null   int64
#  32  koi_slogg          6991 non-null   float64
#  33  koi_slogg_err1     6991 non-null   float64
#  34  koi_slogg_err2     6991 non-null   float64
#  35  koi_srad           6991 non-null   float64
#  36  koi_srad_err1      6991 non-null   float64
#  37  koi_srad_err2      6991 non-null   float64
#  38  ra                 6991 non-null   float64
#  39  dec                6991 non-null   float64
#  40  koi_kepmag         6991 non-null   float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co','koi_fpflag_ec',
                        'koi_period','koi_period_err1','koi_period_err2',
                        'koi_time0bk','koi_time0bk_err1','koi_time0bk_err2',
                        'koi_impact','koi_impact_err1','koi_impact_err2',
                        'koi_duration','koi_duration_err1','koi_duration_err2',
                        'koi_depth','koi_depth_err1','koi_depth_err2',
                        'koi_prad','koi_prad_err1','koi_prad_err2',
                        'koi_teq','koi_insol','koi_insol_err1','koi_insol_err2',
                        'koi_model_snr','koi_steff','koi_steff_err1','koi_steff_err2',
                        'koi_slogg','koi_slogg_err1','koi_slogg_err2',
                        'koi_srad','koi_srad_err1','koi_srad_err2',
                        'ra','dec','koi_kepmag']]

selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 39 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df["koi_disposition"]
X = selected_features

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3563         -0.004110  ...            -133      4.387           0.066
# 4099         -0.004460  ...            -144      4.519           0.078
# 5460         -0.000096  ...            -140      4.594           0.054
# 1091         -0.005290  ...            -112      4.447           0.072
# 5999         -0.028600  ...            -233      4.145           0.164
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3563          -0.123     1.092          0.181         -0.097  298.09543
# 4099          -0.052     0.804          0.056         -0.076  295.73535
# 5460          -0.027     0.683          0.054         -0.060  292.18417
# 1091          -0.108     0.954          0.135         -0.083  283.11377
# 5999          -0.164     1.608          0.905         -0.383  294.93198
#
#             dec  koi_kepmag
# 3563  44.737061      13.204
# 4099  42.576248      15.514
# 5460  49.310040      15.414
# 1091  48.131390      13.328
# 5999  39.812420      12.964
#
# [5 rows x 39 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
# Random Forest

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_minmax, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {rf.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9090389016018307

# %%
sorted(zip(rf.feature_importances_, selected_features), reverse=True)
# Out:
# [(0.09921981119553015, 'koi_fpflag_co'),
#  (0.09878573679140094, 'koi_fpflag_nt'),
#  (0.06019773931831936, 'koi_fpflag_ss'),
#  (0.058487388813167764, 'koi_model_snr'),
#  (0.05487268102355118, 'koi_prad'),
#  (0.041087500572265095, 'koi_fpflag_ec'),
#  (0.03577749780906127, 'koi_steff_err1'),
#  (0.03440935590474936, 'koi_prad_err2'),
#  (0.032740790434880124, 'koi_duration_err2'),
#  (0.03266086833551323, 'koi_prad_err1'),
#  (0.026286146418243835, 'koi_period'),
#  (0.02520664834364867, 'koi_time0bk_err2'),
#  (0.025139566626917322, 'koi_steff_err2'),
#  (0.024898290048176355, 'koi_duration_err1'),
#  (0.02410317442153266, 'koi_duration'),
#  (0.022689542795925968, 'koi_time0bk_err1'),
#  (0.020086026024340207, 'koi_depth'),
#  (0.01864847476210926, 'koi_insol_err1'),
#  (0.018580640455513983, 'koi_teq'),
#  (0.017986365465012828, 'koi_period_err2'),
#  (0.0176196499443139, 'koi_period_err1'),
#  (0.01629089980615565, 'koi_depth_err2'),
#  (0.015001118706210678, 'koi_impact'),
#  (0.014312113078870656, 'koi_insol'),
#  (0.013801016306333087, 'koi_time0bk'),
#  (0.013368288227016169, 'ra'),
#  (0.012039735341696467, 'koi_depth_err1'),
#  (0.011911358257720503, 'koi_insol_err2'),
#  (0.011502959769457956, 'dec'),
#  (0.011367257040379976, 'koi_impact_err2'),
#  (0.011352603376736804, 'koi_kepmag'),
#  (0.010940545575442088, 'koi_impact_err1'),
#  (0.01084968165826477, 'koi_srad_err1'),
#  (0.010631920373831502, 'koi_steff'),
#  (0.009797678934077953, 'koi_slogg_err2'),
#  (0.009623437925253725, 'koi_slogg_err1'),
#  (0.0095196339113304, 'koi_srad'),
#  (0.009322335387847889, 'koi_slogg'),
#  (0.008883520819200439, 'koi_srad_err2')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_minmax, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=125, n_estimators=250, score=0.879, total=   2.6s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.903, total=   2.6s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.890, total=   2.6s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.891, total=   2.6s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.870, total=   2.6s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.882, total=   3.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.899, total=   3.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.891, total=   3.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.888, total=   3.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.872, total=   3.1s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.884, total=   3.7s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.900, total=   3.6s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.897, total=   3.7s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.891, total=   3.7s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.874, total=   3.7s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.882, total=   2.9s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.902, total=   2.7s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.901, total=   2.8s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.891, total=   2.6s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.878, total=   2.6s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.884, total=   3.1s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.898, total=   3.1s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.899, total=   3.1s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.894, total=   3.1s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.875, total=   3.1s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.884, total=   3.7s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.902, total=   3.6s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.902, total=   3.6s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.889, total=   3.6s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.874, total=   3.6s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.883, total=   2.6s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.901, total=   2.6s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.900, total=   2.6s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.894, total=   2.7s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.877, total=   2.6s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.880, total=   3.2s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.900, total=   3.1s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.895, total=   3.1s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.896, total=   3.1s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.872, total=   3.1s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.886, total=   3.6s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.901, total=   3.6s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.898, total=   3.7s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.894, total=   3.6s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.878, total=   3.6s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  2.3min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [125, 150, 175],
#                          'n_estimators': [250, 300, 350]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 175, 'n_estimators': 350}
# 0.8912815913374426

# %%
print(f'Training score: {grid.score(X_train_minmax, y_train)}')
print(f'Testing score: {grid.score(X_test_minmax, y_test)}')
# Out:
# Training score: 1.0
# Testing score: 0.9084668192219679

# %%
predictions = grid.predict(X_test_minmax)
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.84      0.76      0.80       404
#      CONFIRMED       0.81      0.86      0.83       435
# FALSE POSITIVE       0.98      1.00      0.99       909
#
#       accuracy                           0.91      1748
#      macro avg       0.88      0.87      0.87      1748
#   weighted avg       0.91      0.91      0.91      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'james_nguyen_randomforest.sav'
joblib.dump(rf, filename)
# Out:
# ['james_nguyen_randomforest.sav']
